# %% [markdown]
# <h2 style="text-align:center">Дополнительные задания по Python</h2>
#
# <p>В этом документе можно проверить свой код. На проверку его надо вставить в google форму по ссылке: . Там уже указан дедлайн
# </p>
# <p>Выполнение этих заданий не является обязательным для получения зачета</p>

# %% [markdown]
# <h2>Задание 1</h2>
# <p>Назовем пару чисел "интересной", если произведение чисел делится на их разность без остатка.</p>
# <p>Например: 6 и 8 - интересная пара (6*8=48, 6-8=-2; 48 делится на -2), а 5 и 2 - нет.</p>
# <p>Даны два массива целых чисел A и B (числа могут повторятся). Мы составляем все возможные пары чисел, в которых первое число из массива A, а второе из массива B.</p>
# <p>Подсказка: вам могут помочь множества и операции с ними.</p>
# <p>а) Посчитать количество интересных пар.<p>
# <p>б) Посчитать количество интересных пар, чтобы код был в одну строку<p>

# %%
A = [-1, 3, 5, 4, 7, 10]
B = [3, 4, 12, -2, 1, 11]

# Ваш код можно пистаь здесь

# %% [markdown]
# <h2>Задание 2</h2>
# <p>Написать lambda-функцию, которая вычисляет сумму цифр целого числа</p>

# %%
n = 6728126912
sum_of_digits = lambda x: #ваш код можно писать здесь
print(sum_of_digits(n))

# %% [markdown]
# <h2>Задание 3</h2>
# <p>Дан список участников, каждый элемент содержит строку вида "<Имя><пробел><Фамилия>". Отсортируйте список по фамилиям.</p>

# %%
participants = ["Иван Петров", "Петр Сидоров", "Сидор Николаев", "Николай Фомин", "Фома Иванов"]

# Ваш код можно пистаь здесь

# %% [markdown]
# <h2>Задание 4</h2>
# <p>Будем называть стоимостью буквы ее порядковый номер (начиная с единицы: "а" - 1, "б" - 2 и так далее). Напишите функцию, которая возвращает стоимость слова.</p>
# <p>а) Слово состоит только из строчных букв кириллицы</p>
# <p>б) Слово может содержать строчные и прописные буквы кириллицы, а так же дефис (его стоимость - 0)</p>

# %%
word_a = "синхрофазотрон"
word_b = "абра-кадабра"


def word_points_a(word):
    pass # оператор-заглушка, равноценный отсутствию операции

    #ваш код можно писать здесь
    
def word_points_b(word):
    pass # оператор-заглушка, равноценный отсутствию операции

    #ваш код можно писать здесь

score_a = word_points_a(word_a)
print(score_a)

score_b = word_points_b(word_b)
print(score_b)
